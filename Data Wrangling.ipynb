# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_colwidth",None)

# %%
df1=pd.read_csv('Dec_2020_Tweets_Hydrated.csv',usecols=[2,5,14,18])

# %%
df2=pd.read_csv('Dec_2021_Tweets_Hydrated.csv',usecols=[2,5,14,18])

# %%
df3= pd.read_csv('vaccination_all_tweets.csv',usecols=[10,11,13,14])

# %%
df1_clean=df1[df1.hashtags!='โควิดสมุทรสาคร']

# %%
df1_clean.head()
# Out:
#   coordinates                      created_at hashtags  \
# 0         NaN  Sun Dec 20 02:15:57 +0000 2020      NaN
# 2         NaN  Sun Dec 20 02:15:56 +0000 2020      NaN
# 3         NaN  Sun Dec 20 02:15:58 +0000 2020      NaN
# 4         NaN  Sun Dec 20 02:15:57 +0000 2020      NaN
# 5         NaN  Sun Dec 20 02:15:57 +0000 2020      NaN
#
#                                                          media  \
# 0                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
# 5  https://twitter.com/sdut/status/1340479544642265088/photo/1
#
#                            urls  favorite_count                   id  \
# 0                           NaN               0  1340481033184141312
# 2                           NaN               0  1340481026292920322
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952363 entries, 0 to 1952362
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   favorite_count  int64
#  1   retweet_count   int64
#  2   text            object
# dtypes: int64(2), object(1)
# memory usage: 44.7+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206967 entries, 0 to 206966
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   text       206967 non-null  object
#  1   retweets   206967 non-null  int64
#  2   favorites  206967 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.7+ MB

# %%
df3=df3.rename(columns={"retweets": "retweet_count", "favorites": "favorite_count"})

# %%
df1.head()
# Out:
#    favorite_count  retweet_count  \
# 0               0            762
# 1               0             81
# 2               0            360
# 3               0           1951
# 4               1              0
#
#                                                 text
# 0  Another “lawmaker” getting the VACCINE before ...
# 1  Read the news made me feel hurt..\nPlease prot...
# 2  Only 2 weeks ago they encouraged everyone to g...
# 3  Constraining the powers of the Federal Reserve...
# 4  @Utsava4 @realDonaldTrump Utsava, what do you ...

# %%
df1=df1[['text','favorite_count','retweet_count']]

# %%
df2=df2[['text','favorite_count','retweet_count']]

# %%
df3=df3[['text','favorite_count','retweet_count']]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2875055 entries, 0 to 2875054
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   text            object
#  1   favorite_count  int64
#  2   retweet_count   int64
# dtypes: int64(2), object(1)
# memory usage: 65.8+ MB

# %%
df1.head()
# Out:
#                                                 text  favorite_count  \
# 0  Another “lawmaker” getting the VACCINE before ...               0
# 1  Read the news made me feel hurt..\nPlease prot...               0
# 2  Only 2 weeks ago they encouraged everyone to g...               0
# 3  Constraining the powers of the Federal Reserve...               0
# 4  @Utsava4 @realDonaldTrump Utsava, what do you ...               1
#
#    retweet_count
# 0            762
# 1             81
# 2            360
# 3           1951
# 4              0

# %%
df2.head()
# Out:
#                                                 text  favorite_count  \
# 0  Basically someone with a cold got covid.Throug...               0
# 1  President Joe Biden’s federal vaccine mandate ...               0
# 2  We can thank Joe Manchin and Jon Tester for th...               0
# 3  Total Covid Death Distribution by County  For ...               0
# 4  BioNTech CEO says upcoming vaccine for the Omi...               0
#
#    retweet_count
# 0              0
# 1            435
# 2            256
# 3              2
# 4           1624

# %%
df3.head()
# Out:
#                                                 text  favorite_count  \
# 0  Same folks said daikon paste could treat a cyt...               0
# 1  While the world has been on the wrong side of ...               1
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...               0
# 3  Facts are immutable, Senator, even when you're...            2129
# 4  Explain to me again why we need a vaccine @Bor...               0
#
#    retweet_count
# 0              0
# 1              1
# 2              0
# 3            446
# 4              0

# %%
full_df=pd.concat([df1, df2, df3], ignore_index=True)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5034385 entries, 0 to 5034384
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   text            object
#  1   favorite_count  int64
#  2   retweet_count   int64
# dtypes: int64(2), object(1)
# memory usage: 115.2+ MB

# %%
full_df=pd.DataFrame(full_df.text.reset_index(drop=True))

# %%
full_df
# Out:
#                                                       text
# 0        Another “lawmaker” getting the VACCINE before ...
# 1        Read the news made me feel hurt..\nPlease prot...
# 2        Only 2 weeks ago they encouraged everyone to g...
# 3        Constraining the powers of the Federal Reserve...
# 4        @Utsava4 @realDonaldTrump Utsava, what do you ...
# ...                                                    ...
# 5034380  45+ #URBAN #Bengaluru #CovidVaccine Availabili...
# 5034381  Pincode: 560011\nSPUTNIK V - Dose 1: 100 slots...
# 5034382  18-44 #BBMP #Bengaluru #CovidVaccine Availabil...
# 5034383  18-44 #URBAN #Bengaluru #CovidVaccine Availabi...
# 5034384  45+ #URBAN #Bengaluru #CovidVaccine Availabili...
#
# [5034385 rows x 1 columns]

# %%
full_df.to_csv('Final_Dataset.csv',index=False)
